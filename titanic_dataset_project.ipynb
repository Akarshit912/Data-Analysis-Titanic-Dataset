# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Load & Inspect<br>
# Load the dataset into a Pandas DataFrame.<br>
# Show the number of rows, columns, and first 10 rows.<br>

# %%
df=pd.read_csv('titainic.csv')

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# 2. Basic Statistics
#
# Find average age of passengers.
#
# Find survival rate (overall survival percentage).
#
# Count how many males vs. females survived.

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Survived'].mean()
# Out:
# 0.3838383838383838

# %%
df[['Sex','Survived']].groupby('Sex').count()
# Out:
#         Survived
# Sex
# female       314
# male         577

# %% [markdown]
# 3. Missing Values
#
# Check for missing values in each column.
#
# Fill missing ages with the median age.
#
# Drop any column with >30% missing values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.fillna(df['Age'].median())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop("Cabin",axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 4. Survival by Class & Gender
#
# Survival rate for each Passenger Class (Pclass).
#
# Survival rate comparison between men and women.

# %%
df[['Survived','Pclass']].groupby('Pclass',as_index=False).mean()
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
df[['Sex','Survived']].groupby('Sex').mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %% [markdown]
# 5. Fare & Survival
#
# Find average fare of survivors vs. non-survivors.
#
# Find top 5 passengers who paid the highest fare.

# %%
df[['Survived', 'Fare']].groupby('Survived').mean()
# Out:
#                Fare
# Survived
# 0         22.117887
# 1         48.395408

# %%
df['Fare'].sort_values(ascending=False).head(5)
# Out:
# 258    512.3292
# 737    512.3292
# 679    512.3292
# 88     263.0000
# 27     263.0000
# Name: Fare, dtype: float64

# %% [markdown]
# 6. Age Distribution
#
# Find the survival rate of children (<16 years) vs. adults (>=16 years).

# %%
df[df['Age']<16]['Survived'].mean(numeric_only=True)
# Out:
# 0.5903614457831325

# %%
df[df['Age']>=16]['Survived'].mean(numeric_only=True)
# Out:
# 0.38193343898573695

# %% [markdown]
# 7. Family Factor
#
# Create a new column FamilySize = SibSp + Parch + 1.
#
# See if survival chances increase with family size.

# %%
df['FamilySize']= df['SibSp']+df['Parch']+1

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Survived', 'FamilySize']].groupby('FamilySize').mean()
# Out:
#             Survived
# FamilySize
# 1           0.303538
# 2           0.552795
# 3           0.578431
# 4           0.724138
# 5           0.200000
# 6           0.136364
# 7           0.333333
# 8           0.000000
# 11          0.000000

# %% [markdown]
# 8. Cabin / Deck Analysis
#
# Extract the deck letter from the Cabin column (first letter).
#
# Check survival rate by deck.

# %%
df['Deck']=df['Cabin'].str[:1]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby('Deck').size()
# Out:
# Deck
# A    15
# B    47
# C    59
# D    33
# E    32
# F    13
# G     4
# T     1
# dtype: int64

# %%
df[["Survived","Deck"]].groupby("Deck").mean()
# Out:
#       Survived
# Deck
# A     0.466667
# B     0.744681
# C     0.593220
# D     0.757576
# E     0.750000
# F     0.615385
# G     0.500000
# T     0.000000

# %% [markdown]
# 9. Name Titles
#
# Extract title from Name (e.g., Mr, Mrs, Miss, Master).
#
# Compare survival rate for different titles.

# %%
df['Title'] = df['Name'].str.extract(' ([A-Za-z]+).', expand=False)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Planke', 'Don', 'Rev', 'Billiard',
#        'der', 'Walle', 'Dr', 'Pelsmaeker', 'Mulder', 'y', 'Steen',
#        'Carlo', 'Mme', 'Impe', 'Ms', 'Major', 'Gordon', 'Messemaeker',
#        'Mlle', 'Col', 'Capt', 'Velde', 'the', 'Shawah', 'Jonkheer',
#        'Melkebeke', 'Cruyssen'], dtype=object)

# %%
df['Title'] = df['Title'].replace(['Planke', 'Don', 'Rev', 'Billiard',
       'der', 'Walle', 'Dr', 'Pelsmaeker', 'Mulder', 'y', 'Steen',
       'Carlo', 'Mme', 'Impe', 'Ms', 'Major', 'Gordon', 'Messemaeker',
       'Mlle', 'Col', 'Capt', 'Velde', 'the', 'Shawah', 'Jonkheer',
       'Melkebeke', 'Cruyssen'], 'Other')

# %%
df['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Other'], dtype=object)

# %%
df[['Title', 'Survived']].groupby('Title').mean()
# Out:
#         Survived
# Title
# Master  0.575000
# Miss    0.703911
# Mr      0.157371
# Mrs     0.801653
# Other   0.346939

# %% [markdown]
# 10. Correlation Heatmap
# Use seaborn.heatmap() to visualize correlation between numeric features (Age, Fare, Pclass, Survived).

# %%
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
# FamilySize     -0.040143  0.016639  0.065997 -0.301914  0.890712  0.783111
#
#                  Fare  FamilySize
# PassengerId  0.012658   -0.040143
# Survived     0.257307    0.016639
# Pclass      -0.549500    0.065997
# Age          0.096067   -0.301914
# SibSp        0.159651    0.890712
# Parch        0.216225    0.783111
# Fare         1.000000    0.217138
# ...

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# 11. Survival Report Generator
#
#
#
# Input: Gender, Age group (child/adult), Class.
#
# Output: Probability of survival (based on dataset).

# %%
def Find_probability(age,Sex,Class):
    if age<16:
        mask1=df['Age']<16
    else:
        mask1=df['Age']>=16
    mask2=df['Sex']==Sex
    mask3=df['Pclass']==Class
    new=df[mask1 & mask2  & mask3 ]
    probability=new['Survived'].mean()
    return probability

# %%
Find_probability(35,'female',1)
# Out:
# 0.975609756097561
